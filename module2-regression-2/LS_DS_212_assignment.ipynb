# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 2*
#
# ---

# %% [markdown]
# # Regression 2
#
# ## Assignment
#
# You'll continue to **predict how much it costs to rent an apartment in NYC,** using the dataset from renthop.com.
#
# - [ ] Do train/test split. Use data from April & May 2016 to train. Use data from June 2016 to test.
# - [ ] Engineer at least two new features. (See below for explanation & ideas.)
# - [ ] Fit a linear regression model with at least two features.
# - [ ] Get the model's coefficients and intercept.
# - [ ] Get regression metrics RMSE, MAE, and $R^2$, for both the train and test data.
# - [ ] What's the best test MAE you can get? Share your score and features used with your cohort on Slack!
# - [ ] As always, commit your notebook to your fork of the GitHub repo.
#
#
# #### [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
#
# > "Some machine learning projects succeed and some fail. What makes the difference? Easily the most important factor is the features used." — Pedro Domingos, ["A Few Useful Things to Know about Machine Learning"](https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf)
#
# > "Coming up with features is difficult, time-consuming, requires expert knowledge. 'Applied machine learning' is basically feature engineering." — Andrew Ng, [Machine Learning and AI via Brain simulations](https://forum.stanford.edu/events/2011/2011slides/plenary/2011plenaryNg.pdf)
#
# > Feature engineering is the process of using domain knowledge of the data to create features that make machine learning algorithms work.
#
# #### Feature Ideas
# - Does the apartment have a description?
# - How long is the description?
# - How many total perks does each apartment have?
# - Are cats _or_ dogs allowed?
# - Are cats _and_ dogs allowed?
# - Total number of rooms (beds + baths)
# - Ratio of beds to baths
# - What's the neighborhood, based on address or latitude & longitude?
#
# ## Stretch Goals
# - [ ] If you want more math, skim [_An Introduction to Statistical Learning_](http://faculty.marshall.usc.edu/gareth-james/ISL/ISLR%20Seventh%20Printing.pdf),  Chapter 3.1, Simple Linear Regression, & Chapter 3.2, Multiple Linear Regression
# - [ ] If you want more introduction, watch [Brandon Foltz, Statistics 101: Simple Linear Regression](https://www.youtube.com/watch?v=ZkjP5RJLQF4)
# (20 minutes, over 1 million views)
# - [ ] Add your own stretch goal(s) !

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'
    
# Ignore this Numpy warning when using Plotly Express:
# FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')

# %%
import numpy as np
import pandas as pd

# Read New York City apartment rental listing data
df = pd.read_csv(DATA_PATH+'apartments/renthop-nyc.csv')
assert df.shape == (49352, 34)

# Remove the most extreme 1% prices,
# the most extreme .1% latitudes, &
# the most extreme .1% longitudes
df = df[(df['price'] >= np.percentile(df['price'], 0.5)) & 
        (df['price'] <= np.percentile(df['price'], 99.5)) & 
        (df['latitude'] >= np.percentile(df['latitude'], 0.05)) & 
        (df['latitude'] < np.percentile(df['latitude'], 99.95)) &
        (df['longitude'] >= np.percentile(df['longitude'], 0.05)) & 
        (df['longitude'] <= np.percentile(df['longitude'], 99.95))]

# %%
pd.set_option('display.max_columns', None)

# %%
df

# %%
df.describe()

# %%
df.dtypes

# %%
df.created = pd.to_datetime(df.created, infer_datetime_format=True)

# %%
train =  df[(df['created'] >= '2016-04-01') & (df['created'] <= '2016-05-31')]

# %%
train

# %%
test = df[(df['created'] >= '2016-06-01') & (df['created'] <= '2016-06-30')]

# %%
test

# %%
train.shape, test.shape

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_interest = LabelEncoder()

# %%
df['interest_level'] = le_interest.fit_transform(df['interest_level'])

# %%
df.isnull().sum()

# %%
pet_friendly = ((df.cats_allowed == 1) & (df.dogs_allowed == 1))

# %%
df['pet_friendly'] = (df.cats_allowed + df.dogs_allowed)

# %%
df.pet_friendly.value_counts()

# %%
df['pet_friend'] = df['pet_friendly'] == 2

# %%
df = df.drop(['pet_friendly'],axis=1)

# %%
df

# %%
list(df)

# %%
le_pet = LabelEncoder()
df['pet_friend'] = le_pet.fit_transform(df['pet_friend'])

# %%
df['total_rooms'] = (df.bedrooms + df.bathrooms)

# %%
target = ['price']
feature = ['interest_level',
 'hardwood_floors',
 'doorman',
 'elevator',
 'no_fee',
 'laundry_in_building',
 'fitness_center',
 'laundry_in_unit',
 'roof_deck',
 'outdoor_space',
 'dining_room',
 'high_speed_internet',
 'balcony',
 'terrace',
 'wheelchair_access',
 'total_rooms','longitude','latitude','pet_friend']

# %%
X_train = train[feature]
X_test = test[feature]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4e7ea236c483> in <module>
# ----> 1 X_train = train[feature]
#       2 X_test = test[feature]
#
# NameError: name 'train' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
Y_test = test[target]
Y_train = train[target]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-86dbdac4d469> in <module>
# ----> 1 Y_test = test[target]
#       2 Y_train = train[target]
#
# NameError: name 'test' is not defined

# %%
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f526595d08c3> in <module>
# ----> 1 model.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred_train = model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-740a45017645> in <module>
# ----> 1 y_pred_train = model.predict(X_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.metrics import mean_absolute_error
y_pred_train = model.predict(X_train)
mae = mean_absolute_error(Y_train, y_pred_train)
print('Train Error: $',mae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8f32703fe3a7> in <module>
#       1 from sklearn.metrics import mean_absolute_error
# ----> 2 y_pred_train = model.predict(X_train)
#       3 mae = mean_absolute_error(Y_train, y_pred_train)
#       4 print('Train Error: $',mae)
#
# NameError: name 'X_train' is not defined

# %%
y_pred_test = model.predict(X_test)
mae_t = mean_absolute_error(Y_test, y_pred_test)
print('Test Error: $',mae_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f5c6aa854313> in <module>
# ----> 1 y_pred_test = model.predict(X_test)
#       2 mae_t = mean_absolute_error(Y_test, y_pred_test)
#       3 print('Test Error: $',mae_t)
#
# NameError: name 'X_test' is not defined

# %%
print('Intercept:', model.intercept_,'Coefficients: ', model.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-3b4c0331e808> in <module>
# ----> 1 print('Intercept:', model.intercept_,'Coefficients: ', model.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mse_train = mean_squared_error(Y_train, y_pred_train)
print('Mean Square error (Train):',mse_train)
rmse_train = np.sqrt(mse_train)
print('Root Mean Square error (Train):',np.sqrt(mse_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e9789c6ae9ca> in <module>
# ----> 1 mse_train = mean_squared_error(Y_train, y_pred_train)
#       2 print('Mean Square error (Train):',mse_train)
#       3 rmse_train = np.sqrt(mse_train)
#       4 print('Root Mean Square error (Train):',np.sqrt(mse_train))
#
# NameError: name 'Y_train' is not defined

# %%
mse_test = mean_squared_error(Y_test, y_pred_test)
print('Mean Square error (Test):',mse_test)
rmse_test = np.sqrt(mse_test)
print('Root Mean Square error (Test):',np.sqrt(mse_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5a80edf16e60> in <module>
# ----> 1 mse_test = mean_squared_error(Y_test, y_pred_test)
#       2 print('Mean Square error (Test):',mse_test)
#       3 rmse_test = np.sqrt(mse_test)
#       4 print('Root Mean Square error (Test):',np.sqrt(mse_test))
#
# NameError: name 'Y_test' is not defined

# %%
r2_train = r2_score(Y_train, y_pred_train)
print('R^2 scores (Train):',r2_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3dca17f67149> in <module>
# ----> 1 r2_train = r2_score(Y_train, y_pred_train)
#       2 print('R^2 scores (Train):',r2_train)
#
# NameError: name 'Y_train' is not defined

# %%
r2_test = r2_score(Y_test, y_pred_test)
print('R^2 scores (Test):',r2_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c47af35f07f9> in <module>
# ----> 1 r2_test = r2_score(Y_test, y_pred_test)
#       2 print('R^2 scores (Test):',r2_test)
#
# NameError: name 'Y_test' is not defined

# %%
print('Train Absolute Error: $',mae)
print('Test Absolute Error: $',mae_t)
print('Mean Square error (Train):',mse_train)
print('Root Mean Square error (Train):',np.sqrt(mse_train))
print('Mean Square error (Test):',mse_test)
print('Root Mean Square error (Test):',np.sqrt(mse_test))
print('R^2 scores (Train):',r2_train)
print('R^2 scores (Test):',r2_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3ed6f12df6c6> in <module>
# ----> 1 print('Train Absolute Error: $',mae)
#       2 print('Test Absolute Error: $',mae_t)
#       3 print('Mean Square error (Train):',mse_train)
#       4 print('Root Mean Square error (Train):',np.sqrt(mse_train))
#       5 print('Mean Square error (Test):',mse_test)
#
# NameError: name 'mae' is not defined

# %%
import plotly.express as px
test_data = df
fig = px.scatter_matrix(test_data, dimensions=['laundry_in_building'], color="price")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5045fdde09d9> in <module>
#       1 import plotly.express as px
# ----> 2 test_data = df
#       3 fig = px.scatter_matrix(test_data, dimensions=['laundry_in_building'], color="price")
#       4 fig.show()
#
# NameError: name 'df' is not defined

# %%
list(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0a1b9dee78a8> in <module>
# ----> 1 list(df)
#
# NameError: name 'df' is not defined
